# %% [markdown]
# ## Preparing the data for YOLO

# %% [markdown]
# * YOLO needs one txt file per image, and one line per bounding box. With this format: class_id ,x_center, y_center, width, height
# * All the lengths and coordinates need to be normalized

# %%
class_mapping = {
    "RBC": 0,
    "WBC": 1,
    "Platelets": 2
}

# %%
import os
import shutil
import random
import cv2

# %% [markdown]
# ### Shuffle and split the dataset into training and validation sets and put them in their folders

# %%
source_images_dir = "images"
dataset_root = "dataset"

# %%
#get all the image file names
all_filenames = [f for f in os.listdir(source_images_dir)]

random.seed(42) # For reproducibility of results
random.shuffle(all_filenames)

#split by index
split_index = int(len(all_filenames) * 0.8)
train_files = all_filenames[:split_index]
val_files = all_filenames[split_index:]

#achieve the actual split by copying images to their
for filename in train_files:
    src = os.path.join(source_images_dir, filename)
    dst = os.path.join(dataset_root, "train", "images", filename)
    shutil.copy(src, dst)

for filename in val_files:
    src = os.path.join(source_images_dir, filename)
    dst = os.path.join(dataset_root, "val", "images", filename)
    shutil.copy(src, dst)

# %% [markdown]
# ### Read the bounding box annotations from CSV and convert to YOLO. Then split them.

# %%
image_sizes = {}  # cache each image's size so it is read once, not once per box
with open('data.csv', 'r') as f:
    for line in f:
        #read the line
        (filename, class_name, x1, y1, x2, y2) = line.strip().split(',')

        #for splitting
        if filename in train_files:
            split_folder = "train"
        else:
            split_folder = "val"

        class_id = class_mapping[class_name]
        
        width = int(x2) - int(x1)
        height = int(y2) - int(y1)
        
        x_center = int(x1) + width / 2
        y_center = int(y1) + height / 2
        
        #normalizing (read each image once, then reuse its cached size)
        if filename not in image_sizes:
            img = cv2.imread(f"images/{filename}")
            image_sizes[filename] = img.shape[:2]
        img_height, img_width = image_sizes[filename]
        x_center /= img_width
        y_center /= img_height
        width /= img_width
        height /= img_height
        
        #save the new labels file with the same name of the image file
        txt_filename = filename.rsplit('.', 1)[0] + ".txt"
        dst_txt_path = os.path.join(dataset_root, split_folder, "labels", txt_filename)

        with open(dst_txt_path, 'a') as out_f:
            out_f.write(f"{class_id} {x_center:.6f} {y_center:.6f} {width:.6f} {height:.6f}\n")

# %% [markdown]
# ### Train on YOLOv5 model

# %%
from ultralytics import YOLO
model = YOLO('yolov5n.pt')
# Out:
# PRO TIP 💡 Replace 'model=yolov5n.pt' with new 'model=yolov5nu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.

# %%
results = model.train(
    data='dataset/data.yaml',
    epochs=15,
    imgsz=640,
    project='blood_cell_project',
    name='yolov5_run',
)

metrics = model.val()
print(f"mAP50: {metrics.box.map50}")
# Out:
# Ultralytics 8.3.235 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=False, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/root/.cache/kagglehub/datasets/omarelhakim0/blood-object-detection/versions/2/dataset/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=15, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov5n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=yolov5_run, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=blood_cell_project, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/content/blood_cell_project/yolov5_run, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1760  ultralytics.nn.modules.conv.Conv             [3, 16, 6, 2, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      4800  ultralytics.nn.modules.block.C3              [32, 32, 1]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     29184  ultralytics.nn.modules.block.C3              [64, 64, 2]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  3    156928  ultralytics.nn.modules.block.C3              [128, 128, 3]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    296448  ultralytics.nn.modules.block.C3              [256, 256, 1]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1     33024  ultralytics.nn.modules.conv.Conv             [256, 128, 1, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1     90880  ultralytics.nn.modules.block.C3              [256, 128, 1, False]
#  14                  -1  1      8320  ultralytics.nn.modules.conv.Conv             [128, 64, 1, 1]
#  15                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  16             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  17                  -1  1     22912  ultralytics.nn.modules.block.C3              [128, 64, 1, False]
#  18                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  19            [-1, 14]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  20                  -1  1     74496  ultralytics.nn.modules.block.C3              [128, 128, 1, False]
#  21                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  22            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  23                  -1  1    296448  ultralytics.nn.modules.block.C3              [256, 256, 1, False]
#  24        [17, 20, 23]  1    751897  ultralytics.nn.modules.head.Detect           [3, [64, 128, 256]]
# YOLOv5n summary: 153 layers, 2,509,049 parameters, 2,509,033 gradients, 7.2 GFLOPs
#
# Transferred 391/427 items from pretrained weights
# Freezing layer 'model.24.dfl.conv.weight'
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 580.4±218.9 MB/s, size: 20.2 KB)
# train: Scanning /root/.cache/kagglehub/datasets/omarelhakim0/blood-object-detection/versions/2/dataset/train/labels.cache... 291 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 291/291 475.3Kit/s 0.0s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 617.9±342.4 MB/s, size: 20.6 KB)
# val: Scanning /root/.cache/kagglehub/datasets/omarelhakim0/blood-object-detection/versions/2/dataset/val/labels.cache... 73 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 73/73 15.1Kit/s 0.0s
# Plotting labels to /content/blood_cell_project/yolov5_run/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001429, momentum=0.9) with parameter groups 69 weight(decay=0.0), 76 weight(decay=0.0005), 75 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/blood_cell_project/yolov5_run
# Starting training for 15 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/15      4.67G      1.447      3.063      1.481         63        640: 100% ━━━━━━━━━━━━ 19/19 2.5it/s 7.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 3.2it/s 1.0s
#                    all         73        977      0.933      0.123      0.441      0.249
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/15      4.68G       1.29      1.719      1.301         45        640: 100% ━━━━━━━━━━━━ 19/19 3.3it/s 5.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.0it/s 0.6s
#                    all         73        977      0.858      0.349      0.478      0.287
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/15       4.7G      1.239      1.255      1.277         70        640: 100% ━━━━━━━━━━━━ 19/19 2.9it/s 6.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 4.4it/s 0.7s
#                    all         73        977      0.851      0.612      0.732       0.48
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/15      4.71G       1.18      1.145      1.246         32        640: 100% ━━━━━━━━━━━━ 19/19 3.4it/s 5.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.2it/s 0.6s
#                    all         73        977       0.66       0.78      0.874      0.566
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/15      4.72G      1.183      1.098      1.234         45        640: 100% ━━━━━━━━━━━━ 19/19 2.9it/s 6.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 4.1it/s 0.7s
#                    all         73        977      0.713      0.814      0.895      0.564
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/15      4.72G      1.116      1.147      1.171         40        640: 100% ━━━━━━━━━━━━ 19/19 2.7it/s 7.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.1it/s 0.6s
#                    all         73        977      0.822      0.869      0.901      0.591
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/15      4.72G      1.103       1.09      1.159         33        640: 100% ━━━━━━━━━━━━ 19/19 3.1it/s 6.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 4.7it/s 0.6s
#                    all         73        977      0.783      0.892      0.904      0.611
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/15      4.75G      1.083      1.035      1.138         30        640: 100% ━━━━━━━━━━━━ 19/19 3.1it/s 6.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.9it/s 1.0s
#                    all         73        977      0.782      0.915      0.915      0.626
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/15      4.75G      1.066     0.9994      1.127         35        640: 100% ━━━━━━━━━━━━ 19/19 3.1it/s 6.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 4.4it/s 0.7s
#                    all         73        977      0.861      0.845      0.921      0.622
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/15      4.75G       1.07     0.9622      1.117         37        640: 100% ━━━━━━━━━━━━ 19/19 3.5it/s 5.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 4.5it/s 0.7s
#                    all         73        977      0.854      0.898       0.92      0.632
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/15      4.75G      1.053     0.9298      1.113         41        640: 100% ━━━━━━━━━━━━ 19/19 3.2it/s 5.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.1it/s 0.6s
#                    all         73        977      0.862      0.876      0.913       0.61
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/15      4.75G      1.044     0.9092      1.106         45        640: 100% ━━━━━━━━━━━━ 19/19 3.5it/s 5.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 3.5it/s 0.9s
#                    all         73        977       0.85      0.915      0.919      0.622
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/15      4.75G      1.026     0.8933      1.102         48        640: 100% ━━━━━━━━━━━━ 19/19 3.3it/s 5.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 4.9it/s 0.6s
#                    all         73        977      0.855      0.914      0.923      0.639
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/15      4.75G      1.027     0.8944      1.107         33        640: 100% ━━━━━━━━━━━━ 19/19 3.5it/s 5.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 3.0it/s 1.0s
#                    all         73        977      0.873      0.892      0.923      0.639
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/15      4.75G      1.015     0.8674      1.088         24        640: 100% ━━━━━━━━━━━━ 19/19 3.4it/s 5.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.4it/s 0.6s
#                    all         73        977       0.86      0.913      0.928      0.642
#
# 15 epochs completed in 0.030 hours.
# Optimizer stripped from /content/blood_cell_project/yolov5_run/weights/last.pt, 5.3MB
# Optimizer stripped from /content/blood_cell_project/yolov5_run/weights/best.pt, 5.3MB
#
# Validating /content/blood_cell_project/yolov5_run/weights/best.pt...
# Ultralytics 8.3.235 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv5n summary (fused): 84 layers, 2,503,529 parameters, 0 gradients, 7.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.5it/s 2.1s
#                    all         73        977       0.86      0.913      0.928      0.642
#                    RBC         69        823      0.781      0.854      0.901      0.653
#                    WBC         72         76       0.98      0.987      0.975      0.768
#              Platelets         39         78      0.819      0.897      0.909      0.506
# Speed: 0.2ms preprocess, 5.3ms inference, 0.0ms loss, 3.9ms postprocess per image
# Results saved to /content/blood_cell_project/yolov5_run
# Ultralytics 8.3.235 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv5n summary (fused): 84 layers, 2,503,529 parameters, 0 gradients, 7.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 820.2±276.8 MB/s, size: 20.4 KB)
# val: Scanning /root/.cache/kagglehub/datasets/omarelhakim0/blood-object-detection/versions/2/dataset/val/labels.cache... 73 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 73/73 125.1Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.7it/s 3.0s
#                    all         73        977       0.86      0.913      0.928      0.642
#                    RBC         69        823      0.781      0.854      0.901      0.653
#                    WBC         72         76       0.98      0.987      0.975      0.768
#              Platelets         39         78      0.819      0.897      0.909      0.506
# Speed: 4.9ms preprocess, 3.9ms inference, 0.0ms loss, 3.5ms postprocess per image
# Results saved to /content/runs/detect/val2
# mAP50: 0.9282929595332922

# %%
import matplotlib.pyplot as plt
import glob

# %%
#load the best model
model = YOLO('blood_cell_project/yolov5_run/weights/best.pt')

#pick an image from the validation set
val_images = glob.glob('dataset/val/images/*.jpg') 
test_img = random.choice(val_images)

results = model.predict(test_img)

#plot the result
for result in results:
    im_array = result.plot()
    plt.imshow(im_array[..., ::-1]) #BGR to RGB
    plt.axis('off')
    plt.show()
# Out:
# image 1/1 /root/.cache/kagglehub/datasets/omarelhakim0/blood-object-detection/versions/2/dataset/val/images/BloodImage_00353.jpg: 480x640 24 RBCs, 1 WBC, 6.4ms
# Speed: 1.2ms preprocess, 6.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# Saved prediction_sample.jpg
